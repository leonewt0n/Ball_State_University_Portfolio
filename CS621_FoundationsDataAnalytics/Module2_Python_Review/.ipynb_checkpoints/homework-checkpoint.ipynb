# %%
data_i = [17, 39, 21, 85, 29, 31, 19, 83, 71, 11, 59, 57, 20, 35, 24, 42, 53, 16, 52, 71, 59, 67, 34, 36, 78, 41, 64, 45, 53, 45, 29, 47, 19, 44, 60, 29, 54, 34, 50, 11, 83, 41, 82, 61, 72, 79, 22, 14, 65, 14, 80, 35, 47, 39, 56, 45, 74, 48, 36, 63, 58, 46, 30, 28, 27, 56, 29, 12, 30, 48, 77, 78, 67, 12, 42, 61, 23, 28, 49, 74, 39, 32, 61, 77, 84, 67, 62, 57, 62, 37, 39, 73, 84, 16, 85, 59, 68, 71, 15, 71]

# %%
count = 0
for i in data_i:
    count+= 1
print(count)
# Out:
# 100

# %%
data_i.sort()
print(data_i)
85-11
# Out:
# [11, 11, 12, 12, 14, 14, 15, 16, 16, 17, 19, 19, 20, 21, 22, 23, 24, 27, 28, 28, 29, 29, 29, 29, 30, 30, 31, 32, 34, 34, 35, 35, 36, 36, 37, 39, 39, 39, 39, 41, 41, 42, 42, 44, 45, 45, 45, 46, 47, 47, 48, 48, 49, 50, 52, 53, 53, 54, 56, 56, 57, 57, 58, 59, 59, 59, 60, 61, 61, 61, 62, 62, 63, 64, 65, 67, 67, 67, 68, 71, 71, 71, 71, 72, 73, 74, 74, 77, 77, 78, 78, 79, 80, 82, 83, 83, 84, 84, 85, 85]
# 74

# %%
data_s = ['Mango', 'Kiwi', 'Mango', 'Pineapple', 'Mango', 'Banana', 'Apple', 'Banana', 'Pineapple', 'Kiwi', 'Apple', 'Kiwi', 'Banana', 'Banana', 'Mango', 'Pineapple', 'Pineapple', 'Kiwi', 'Banana', 'Banana', 'Mango', 'Apple', 'Apple', 'Mango', 'Pineapple', 'Pineapple', 'Apple', 'Kiwi', 'Mango', 'Mango', 'Apple', 'Apple', 'Mango', 'Kiwi', 'Pineapple', 'Kiwi', 'Apple', 'Mango', 'Apple', 'Mango', 'Mango', 'Banana', 'Mango', 'Kiwi', 'Kiwi', 'Apple', 'Pineapple', 'Mango', 'Banana', 'Kiwi', 'Pineapple', 'Mango', 'Mango', 'Mango', 'Pineapple', 'Kiwi', 'Kiwi', 'Apple', 'Pineapple', 'Pineapple', 'Apple', 'Apple', 'Mango', 'Kiwi', 'Kiwi', 'Mango', 'Mango', 'Kiwi', 'Pineapple', 'Kiwi', 'Mango', 'Kiwi', 'Kiwi', 'Apple', 'Mango', 'Mango', 'Apple', 'Kiwi', 'Kiwi', 'Apple', 'Apple', 'Kiwi', 'Pineapple', 'Pineapple', 'Kiwi', 'Mango', 'Kiwi', 'Mango', 'Kiwi', 'Pineapple', 'Kiwi', 'Mango', 'Apple', 'Pineapple', 'Kiwi', 'Pineapple', 'Kiwi', 'Pineapple', 'Pineapple', 'Banana']

# %%
len(data_s)
# Out:
# 100

# %%
print(set(data_s))
# Out:
# {'Apple', 'Kiwi', 'Pineapple', 'Mango', 'Banana'}

# %%
print(data_s.count('Apple'))
print(data_s.count('Kiwi'))
print(data_s.count('Pineapple'))
print(data_s.count('Mango'))
print(data_s.count('Banana'))
# Out:
# 18
# 27
# 20
# 26
# 9
